# %%
import pandas as pd
from GoogleNews import GoogleNews
from datetime import datetime
import regex as re

pd.set_option('max_colwidth', 10000)

# %%
from scrape_googleNews import *

# %%
top_exchange()
# Out:
# ['binance',
#  'okex',
#  'coinbene',
#  'rightbtc',
#  'huobi korea',
#  'bit-z',
#  'hitbtc',
#  'digifinex',
#  'coineal',
#  'coinbase pro',
#  'dragonex',
#  'bibox',
#  'bitrue',
#  'upbit korea',
#  'sistemkoin',
#  'huobi global',
#  'cointiger',
#  'bithumb',
#  'kraken',
#  'bilaxy',
#  'bitforex',
#  'bitstamp',
#  'hotbit',
#  'bitmart',
#  'simex',
#  'bitfinex',
#  'yobit',
#  'primexbt',
#  'indoex',
#  'aofex',
#  'coinone',
#  'btc-alpha',
#  'liquid',
#  'gate.io',
#  'exx',
#  'lbank',
#  'bitflyer',
#  'poloniex',
#  'coinfield',
#  'stex',
#  'kucoin',
#  'bittrex',
#  'mercatox',
#  'bitinka',
#  'gemini',
#  'p2pb2b',
#  'bitbay',
#  'livecoin',
#  'binance.us',
#  'exmo',
#  'kryptono',
#  'indodax',
#  'bitkub',
#  'zaif',
#  'localbitcoins',
#  'bw',
#  'coindeal',
#  'korbit',
#  'lakebtc',
#  'bitbns',
#  'bcex',
#  'itbit',
#  'btc markets',
#  'btcbox',
#  'bithumb global',
#  'big.one',
#  'crex24',
#  'tidex',
#  'litebit',
#  'cex.io',
#  'idex',
#  'coinfloor',
#  'chaoex',
#  'the rock trading',
#  'tradeogre',
#  'coinmate',
#  'bit2c',
#  'paymium',
#  'bleutrade',
#  'cryptox',
#  'bitx south africa',
#  'boa exchange',
#  'bitkonan',
#  'bitfex',
#  'coins pro',
#  'go4cryptos',
#  'zb.com',
#  'latoken',
#  'binance jersey',
#  'binance dex',
#  'novadax',
#  'acx',
#  'cat.ex',
#  'dobi exchange',
#  'token store',
#  'openledger dex',
#  'idax',
#  'bitubu',
#  'bx thailand',
#  'okcoin',
#  'dsx',
#  'allcoin',
#  'tradesatoshi',
#  'bisq',
#  'virwox',
#  'coinexchange',
#  'coss',
#  'vaultoro',
#  'mxc',
#  'oceanex',
#  'ooobtc',
#  'bitso',
#  'cryptonit',
#  'c-cex',
#  'indacoin',
#  'bitcoins norway',
#  'gatecoin',
#  'vircurex',
#  'quadrigacx',
#  'abucoins',
#  'coincoz',
#  'btcc',
#  'flowbtc',
#  'bitmarket',
#  'coinsecure',
#  'braziliex',
#  'coinnest',
#  'stocks exchange',
#  'cryptobridge',
#  'abcc',
#  'binance uganda',
#  'chaince',
#  'eterbase']

# %%
def scrap_headlines(entity:str, start_date: str, end_date: str):
    
    '''
    Scrap (using GoogleNews API) the top 10 headlines of google news on a particular entity, for a given time range
    Output : Pandas Dataframe with title, short summary, date & url column
    '''
    
    start_date_input=datetime.strptime(start_date, "%Y-%m-%d").strftime("%m-%d-%Y")
    end_date_input=datetime.strptime(end_date, "%Y-%m-%d").strftime("%m-%d-%Y")
    news = GoogleNews(start=start_date_input,end=end_date_input, lang='en', encode='utf-8')
    news.search(f"{entity} crypto")   # Main bulk of time, taking ~2 seconds to search
    
    if pd.DataFrame(news.result()).empty:
        # No relevant articles 
        return pd.DataFrame()
    
    df = pd.DataFrame(news.result())[['title', 'desc', 'date', 'link']]
    
    # Exist date input as '1 month ago' for recent articles
    # df['date'] = pd.to_datetime(df['date'])
    
    # Only get headlines which mention the entity of interest
    df=df[df['title'].str.contains(entity,flags=re.IGNORECASE)].reset_index(drop=True)
    df['entity'] = entity
    
    return df

# %%
df=scrap_headlines('Binance', '2020-06-27','2020-08-10')

# %%
df
# Out:
#                                                                               title  \
# 0  Binance Acquires Crypto Debit Card Provider Swipe for Undisclosed Sum - CoinDesk
# 1                    Binance Buys Crypto Card Issuer Swipe for an “Undisclosed” Sum
# 2                Binance Expands Fiat Gateway to Support 15 New National Currencies
# 3                    Binance Card Launches in Europe, Bridging Crypto and Debit ...
# 4                     Binance Rolling Out Crypto Card for EU, UK Markets - CoinDesk
# 5                        Binance’s Swipe-Powered Crypto Debit Card Debuts in Europe
# 6                                     SC adds crypto exchange Binance to alert list
# 7      Blow To Bitcoin As Binance CEO Makes ‘Safe Haven’ Stock Market Crash Warning
# 8                          Bitcoin reaches $100,000 at Binance, CEO reports failure
# 9                                       Binance launches Australian crypto platform
#
#                                                                                                                                                                      desc  \
# 0                  Exchange giant Binance has acquired crypto wallet app Swipe.io that allows users to purchase items via a Visa debit card. Swipe users can purchase ...
# 1           Binance, one of the leading digital currency exchanges, has announced on Tuesday the acquisition of Swipe, a crypto payments platform, for an undisclosed ...
# 2         Major cryptocurrency exchange Binance has added support for deposits in 15 ... Binance added the new currencies through a partnership with crypto asset and ...
# 3                 LONDON, July 14, 2020 /PRNewswire/ -- Binance, the global blockchain company behind the world's largest digital asset exchange, today announced the ...
# 4       Binance has announced the rollout of its debit card allowing users to pay for goods and services in crypto. Users in the European Economic Area (EEA) will be ...
# 5   Binance Card, a highly anticipated crypto debit card by Binance, will support four cryptocurrencies at launch. 10989 Total views. 68 Total shares. Listen to article.
# 6                  KUALA LUMPUR: The Securities Commission has cautioned that Binance, world's largest crypto currency exchange, does not comply with its securities law.
# 7                                                                                                  I write about how bitcoin, crypto and blockchain can change the world.
# 8  After suffering a failure in the platform's algorithm, crypto exchange Binance registers a Bitcoin (BTC) price of $100,000 in future contracts. Binance will cover ...
# 9  Binance,the global blockchain firm behind the world's largest digital asset exchange by trading volume, today launched Binance Australia, a fiat-to-crypto trading ...
#
#           date  \
# 0  1 month ago
# 1  1 month ago
# 2  1 month ago
# 3  1 month ago
# 4  1 month ago
# 5  1 month ago
# 6  1 month ago
# 7  1 month ago
# 8  3 weeks ago
# 9  1 month ago
#
#                                                                                                                                  link
# 0                                      https://www.coindesk.com/binance-acquires-crypto-debit-card-provider-swipe-for-undisclosed-sum
# 1                   https://www.financemagnates.com/cryptocurrency/news/binance-buys-crypto-card-issuer-swipe-for-an-undisclosed-sum/
# 2                                   https://cointelegraph.com/news/binance-expands-fiat-gateway-to-support-15-new-national-currencies
# 3          https://www.prnewswire.com/news-releases/binance-card-launches-in-europe-bridging-crypto-and-debit-payments-301092961.html
# 4                                                     https://www.coindesk.com/binances-crypto-card-goes-live-for-eu-uk-markets-today
# 5                                            https://cointelegraph.com/news/binances-swipe-powered-crypto-debit-card-debuts-in-europe
# 6                          https://www.thestar.com.my/business/business-news/2020/07/17/sc-adds-crypto-exchange-binance-to-alert-list
# 7  https://www.forbes.com/sites/billybambrough/2020/07/21/blow-to-bitcoin-as-binance-ceo-makes-safe-haven-stock-market-crash-warning/
# 8                                            https://www.crypto-news-flash.com/bitcoin-reaches-100000-at-binance-ceo-reports-failure/
# 9                                             https://www.finextra.com/pressarticle/83493/binance-launches-australian-crypto-platform

# %%
from typing import List

# %%
def scrap_googleNews(start_date: datetime, end_date: datetime, exchanges: List[str]):
    df=pd.DataFrame()
    for ex in exchanges:
        curDf = scrap_headlines(ex, start_date,end_date)
        df=df.append(curDf)
    
    return df

# %%
all = scrap_googleNews('2020-06-27','2020-08-10', top_exchange())

# %%
all.date.unique()
# Out:
# array(['1 month ago', '3 weeks ago', '2 weeks ago', 'Jul 1, 2020',
#        'Jun 28, 2020', '4 weeks ago', 'Jun 30, 2020', 'Jun 27, 2020'],
#       dtype=object)

# %%
all.
# Out:
#                                                                                                                                                                                      title  \
# 0                                                                                                         Binance Acquires Crypto Debit Card Provider Swipe for Undisclosed Sum - CoinDesk
# 1                                                                                                                           Binance Buys Crypto Card Issuer Swipe for an “Undisclosed” Sum
# 2                                                                                                                       Binance Expands Fiat Gateway to Support 15 New National Currencies
# 3                                                                                                                           Binance Card Launches in Europe, Bridging Crypto and Debit ...
# 4                                                                                                                            Binance Rolling Out Crypto Card for EU, UK Markets - CoinDesk
# ..                                                                                                                                                                                     ...
# 0                                                                                                 Kaspersky Fraud Prevention helps Indacoin halt fraudulent operations with cryptocurrency
# 1                                                                                                                                 Elrond now available on Indacoin via Visa And Mastercard
# 0                                                                                                                             Not your keys, not your coins: lessons from QuadrigaCX fraud
# 0                                 Global Crypto Currency Market 2020 – Impact of COVID-19, Future Growth Analysis and Challenges | Bitfinex, BitFury Group, Bitstamp, Coinbase, Coinsecure
# 1   Cryptocurrency Market Report 2020 (Covid-19 Impact Analysis) By Segmentations, Key Company Profiles & Demand Forecasts To 2021 – 2026 | ZEB IT Service, Coinsecure, Coinbase, Bitstamp
#
#                                                                                                                                                                        desc  \
# 0                    Exchange giant Binance has acquired crypto wallet app Swipe.io that allows users to purchase items via a Visa debit card. Swipe users can purchase ...
# 1             Binance, one of the leading digital currency exchanges, has announced on Tuesday the acquisition of Swipe, a crypto payments platform, for an undisclosed ...
# 2           Major cryptocurrency exchange Binance has added support for deposits in 15 ... Binance added the new currencies through a partnership with crypto asset and ...
# 3                   LONDON, July 14, 2020 /PRNewswire/ -- Binance, the global blockchain company behind the world's largest digital asset exchange, today announced the ...
# 4         Binance has announced the rollout of its debit card allowing users to pay for goods and services in crypto. Users in the European Economic Area (EEA) will be ...
# ..                                                                                                                                                                      ...
# 0   The cryptocurrency exchange rate is known to be quite erratic. which means investors rely on their payments being processed very quickly. Indacoin, a leading fiat- ...
# 1                  Crypto purchases with Visa & Mastercard in Russia, UK & +180 countries, ... Being a European cryptocurrency payments processor, Indacoin operates in ...
# 0   Crypto exchanges instead are a place where individuals simply exchange their Bitcoin (or other cryptocurrency) for fiat currency or vice versa. The proceeds of the ...
# 0                 Global Crypto Currency Market 2020 – Impact of COVID-19, Future Growth Analysis and Challenges | Bitfinex, BitFury Group, Bitstamp, Coinbase, Coinsecure.
# 1                   Trending Report on Cryptocurrency Market 2020: COVID-19 Outbreak Impact Analysis. Chicago, United States –The ... Coinsecure Coinbase Bitstamp Litecoin
#
#            date  \
# 0   1 month ago
# 1   1 month ago
# 2   1 month ago
# 3   1 month ago
# 4   1 month ago
# ..          ...
# 0   1 month ago
# 1   1 month ago
# 0   1 month ago
# 0   4 weeks ago
# 1   4 weeks ago
#
#                                                                                                                                                                                                                link
# 0                                                                                                                    https://www.coindesk.com/binance-acquires-crypto-debit-card-provider-swipe-for-undisclosed-sum
# 1                                                                                                 https://www.financemagnates.com/cryptocurrency/news/binance-buys-crypto-card-issuer-swipe-for-an-undisclosed-sum/
# 2                                                                                                                 https://cointelegraph.com/news/binance-expands-fiat-gateway-to-support-15-new-national-currencies
# 3                                                                                        https://www.prnewswire.com/news-releases/binance-card-launches-in-europe-bridging-crypto-and-debit-payments-301092961.html
# 4                                                                                                                                   https://www.coindesk.com/binances-crypto-card-goes-live-for-eu-uk-markets-today
# ..                                                                                                                                                                                                              ...
# 0                                                                                                 https://www.crn.in/news/kaspersky-fraud-prevention-helps-indacoin-halt-fraudulent-operations-with-cryptocurrency/
# 1                                                                                                                             https://www.cryptonewsz.com/elrond-now-available-on-indacoin-via-visa-and-mastercard/
# 0                                                                                                https://www.investmentexecutive.com/news/industry-news/not-your-keys-not-your-coins-lessons-from-quadrigacx-fraud/
# 0                        https://galusaustralis.com/2020/07/781781/global-crypto-currency-market-2020-impact-of-covid-19-future-growth-analysis-and-challenges-bitfinex-bitfury-group-bitstamp-coinbase-coinsecure/
# 1   https://bulletinline.com/2020/07/31/cryptocurrency-market-report-2020-covid-19-impact-analysis-by-segmentations-key-company-profiles-demand-forecasts-to-2021-2026-zeb-it-service-coinsecure-coinbase-bitstamp/
#
# [183 rows x 4 columns]
